# %%
"""Final Project"""

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

N = 100
a = 1
electronarray = np.arange(0,N+1)
locarrayx = np.zeros(N)
locarrayy = np.zeros(N)
jtype = np.zeros(N) #two junction types, each associated with different possible movements(diff nearest neighbor positions)

# %%
b= np.random.randint(0,100)
for i in range(N):
    c = np.random.randint(100)  #to maintain randomness, keep N and the random integer bound equal
    locarrayx[i] = c * 3.*a / 2 #move electron to random 'column'
    locarrayx += a #moves electron to rightmost lattice site for given hexagon
    b = (np.random.randint(100) * a * np.sqrt(3))
    if c % 2 == 0:
        locarrayy[i] =  b 
    else:
        locarrayy[i] = b + a * np.sqrt(3) / 2. #These two different possible y values are due to hexagons in adjacent columns
                                               #having mismatched y values for their centers. 
plt.plot(locarrayx)
plt.plot(locarrayy)
plt.title('x and y distribution for electrons in array with initial coords (should seem random)')
plt.xlabel('x')
plt.ylabel('y')

# %%
plt.scatter(locarrayx,locarrayy)
plt.title("Initial points of N electrons scattered throughout the hexagonal lattice")

# %%
def motions(x, y, jtype, rand): #executes electron hopping for arbitrary hopping and staying values(hop = .2, stay = .4)
    #import numpy as np
    if (jtype % 2.0) == 0:
        if rand < 0.2: #prob of hopping to site 1 
            x = x + a
            y = y
            jtype += 1
        elif rand < 0.4: #prob of hopping to site 1 + prob of hopping to site 2
            x = x - a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6: #prob of hopping to site 1 + prob of hopping to site 2 + prob of hopping to site 3
            x = x - a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        #probability of staying is 1-3(.2)=.4, is implicit (does nothing to x and y)
    else:
        if rand < 0.2:
            x = x - a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x + a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x + a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
    return [x, y, jtype]

def call_function(x,y,jtype,t): #we attempt to execute single electron movement, checks out in that it traces out hexagons
    locarrayx = np.zeros(t)
    locarrayy = np.zeros(t)
    jtype = np.zeros(t)
    rand = np.zeros(t)
    for i in range(99):
        rand[i] = np.random.rand()
        a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
        locarrayx[i+1] = a[0] 
        locarrayy[i+1] = a[1] 
        jtype[i+1] = a[2]
    plt.plot(locarrayx,locarrayy, 'ko-')
    plt.gca().set_aspect('equal')
    plt.grid()
    
call_function(locarrayx,locarrayy,jtype,100)

# %%
#Attempt for an arbitrary number of electrons

def motions(x, y, jtype, rand):
    #import numpy as np
    if (jtype % 2.0) == 0:
        if rand < 0.2:
            x = x + a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x - a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x - a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
    else:
        if rand < 0.2:
            x = x - a
            y = y
            jtype += 1
        elif rand < 0.4:
            x = x + a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6:
            x = x + a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
    return [x, y, jtype]

def call_function(x,y,jtype,t):
    locarrayx = np.zeros(t)
    locarrayy = np.zeros(t)
    jtype = np.zeros(t)
    rand = np.zeros(t)
    for j in range(t):
        for i in range(99):
            rand[i] = np.random.rand()
            a = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
            locarrayx[i+1] = a[0] 
            locarrayy[i+1] = a[1] 
            jtype[i+1] = a[2]
        plt.plot(locarrayx,locarrayy)
    plt.gca().set_aspect('equal')
    plt.grid()
    
call_function(locarrayx,locarrayy,jtype,100)

# %%
def motions(x, y, jtype, rand):

    
    #Here we just combined the initialization function with the motion simulation
    
    if (jtype % 2.0) == 0:
        if rand < 0.2: #prob 1
            x = x + a
            y = y
            jtype += 1
        elif rand < 0.4: #prob 2 + prob 1
            x = x - a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6: #(prob 2 + prob 1) + prob 3
            x = x - a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
    else:
        if rand < 0.2: #prob 1
            x = x - a
            y = y
            jtype += 1
        elif rand < 0.4: #prob 2 + prob 1
            x = x + a/2.0
            y = y - np.sqrt(3.0)*a/2.0
            jtype += 1
        elif rand < 0.6: #(prob 2 + prob 1) + prob 3
            x = x + a/2.0
            y = y + np.sqrt(3.0)*a/2.0
            jtype += 1
    return [x, y, jtype]

def call_function(x,y,jtype,t,N):
    a = 1.0
    locarrayx = np.zeros(N+1)
    locarrayy = np.zeros(N+1)
    jtype = np.zeros(N+1)
    rand = np.zeros(N+1)
    for j in range(t):
        a = 1.0
        c = np.random.randint(10) 
        locarrayx[0] = c * 3.*a / 2
        locarrayx[0] += a
        b = (np.random.randint(100) * a * np.sqrt(3))
        if c % 2 == 0:
            locarrayy[0] =  b
        else:
            locarrayy[0] = b + a * np.sqrt(3) / 2.    
        for i in range(N):
            rand[i] = np.random.rand()
            z = motions(locarrayx[i],locarrayy[i],jtype[i],rand[i])
            locarrayx[i+1] = z[0] 
            locarrayy[i+1] = z[1] 
            jtype[i+1] = z[2]
        plt.plot(locarrayx,locarrayy)
    plt.grid()
    plt.gca().set_aspect('equal')
    plt.ylim(0,50)
call_function(locarrayx,locarrayy,jtype,100,1000)

# %% [markdown]
# Below we see the results of our test case: a single electron moving coherently throughout the hexagonal lattice. Although
# the coherent movement seen is encouraging, it does not looking quite hexagonal in nature and therefore our next portion will be
# focusing on ironing out this. So far we have achieved this movement as well as the random scattering of initial placement of
# electrons, as shown above

# %% [markdown]
# Looking back now after completing our presentation, our initial test case somehow disappeared. However, we were able to get the motion to reflect that of a hexagonal rather than triangular lattice by fixing a portion of our code that was erroneous in that it was causing the check in junction types to be out of step, checking the previous electron in the array rather than the current one (this was fixed by swithing from jtype[i] to jtype[i+1]

# %%
#Trying out the python Tight Binding Model module

from pythtb import *
# %pylab inline

# lattice vectors and orbital positions
lat=[[1.0, 0.0], [0.5, np.sqrt(3.0)/2.0]]
orb=[[1./3., 1./3.], [2./3., 2./3.]]
gra=tb_model(2, 2, lat, orb)

# define hopping between orbitals
gra.set_hop(-1.0, 0, 1, [ 0, 0])
gra.set_hop(-1.0, 1, 0, [ 1, 0])
gra.set_hop(-1.0, 1, 0, [ 0, 1])

# solve model on path in k-space
path=[[1.0, 0.0], [0.0, 1.0]]
kpts=k_path(path, 150)
print(kpts)
evals=gra.solve_all(kpts)

# plot bandstructure
import matplotlib.pyplot as plt
plt.plot(evals[0, :])
plt.plot(evals[1, :])
plt.savefig("band.png")
plt.title('Graphene dispersion relation')
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [[ 1.          0.        ]
#  [ 0.99333333  0.00666667]
#  [ 0.98666667  0.01333333]
#  [ 0.98        0.02      ]
#  [ 0.97333333  0.02666667]
#  [ 0.96666667  0.03333333]
#  [ 0.96        0.04      ]
#  [ 0.95333333  0.04666667]
#  [ 0.94666667  0.05333333]
#  [ 0.94        0.06      ]
#  [ 0.93333333  0.06666667]
#  [ 0.92666667  0.07333333]
#  [ 0.92        0.08      ]
#  [ 0.91333333  0.08666667]
#  [ 0.90666667  0.09333333]
#  [ 0.9         0.1       ]
#  [ 0.89333333  0.10666667]
#  [ 0.88666667  0.11333333]
#  [ 0.88        0.12      ]
#  [ 0.87333333  0.12666667]
#  [ 0.86666667  0.13333333]
#  [ 0.86        0.14      ]
#  [ 0.85333333  0.14666667]
#  [ 0.84666667  0.15333333]
#  [ 0.84        0.16      ]
#  [ 0.83333333  0.16666667]
#  [ 0.82666667  0.17333333]
#  [ 0.82        0.18      ]
#  [ 0.81333333  0.18666667]
#  [ 0.80666667  0.19333333]
#  [ 0.8         0.2       ]
#  [ 0.79333333  0.20666667]
#  [ 0.78666667  0.21333333]
#  [ 0.78        0.22      ]
#  [ 0.77333333  0.22666667]
#  [ 0.76666667  0.23333333]
#  [ 0.76        0.24      ]
#  [ 0.75333333  0.24666667]
#  [ 0.74666667  0.25333333]
#  [ 0.74        0.26      ]
#  [ 0.73333333  0.26666667]
#  [ 0.72666667  0.27333333]
#  [ 0.72        0.28      ]
#  [ 0.71333333  0.28666667]
#  [ 0.70666667  0.29333333]
#  [ 0.7         0.3       ]
#  [ 0.69333333  0.30666667]
#  [ 0.68666667  0.31333333]
#  [ 0.68        0.32      ]
#  [ 0.67333333  0.32666667]
#  [ 0.66666667  0.33333333]
#  [ 0.66        0.34      ]
#  [ 0.65333333  0.34666667]
#  [ 0.64666667  0.35333333]
#  [ 0.64        0.36      ]
#  [ 0.63333333  0.36666667]
#  [ 0.62666667  0.37333333]
#  [ 0.62        0.38      ]
#  [ 0.61333333  0.38666667]
#  [ 0.60666667  0.39333333]
#  [ 0.6         0.4       ]
#  [ 0.59333333  0.40666667]
#  [ 0.58666667  0.41333333]
#  [ 0.58        0.42      ]
#  [ 0.57333333  0.42666667]
#  [ 0.56666667  0.43333333]
#  [ 0.56        0.44      ]
#  [ 0.55333333  0.44666667]
#  [ 0.54666667  0.45333333]
#  [ 0.54        0.46      ]
#  [ 0.53333333  0.46666667]
#  [ 0.52666667  0.47333333]
#  [ 0.52        0.48      ]
#  [ 0.51333333  0.48666667]
#  [ 0.50666667  0.49333333]
#  [ 0.5         0.5       ]
#  [ 0.49333333  0.50666667]
#  [ 0.48666667  0.51333333]
#  [ 0.48        0.52      ]
#  [ 0.47333333  0.52666667]
#  [ 0.46666667  0.53333333]
#  [ 0.46        0.54      ]
#  [ 0.45333333  0.54666667]
#  [ 0.44666667  0.55333333]
#  [ 0.44        0.56      ]
#  [ 0.43333333  0.56666667]
#  [ 0.42666667  0.57333333]
#  [ 0.42        0.58      ]
#  [ 0.41333333  0.58666667]
#  [ 0.40666667  0.59333333]
#  [ 0.4         0.6       ]
#  [ 0.39333333  0.60666667]
#  [ 0.38666667  0.61333333]
#  [ 0.38        0.62      ]
#  [ 0.37333333  0.62666667]
#  [ 0.36666667  0.63333333]
#  [ 0.36        0.64      ]
#  [ 0.35333333  0.64666667]
#  [ 0.34666667  0.65333333]
#  [ 0.34        0.66      ]
#  [ 0.33333333  0.66666667]
#  [ 0.32666667  0.67333333]
#  [ 0.32        0.68      ]
#  [ 0.31333333  0.68666667]
#  [ 0.30666667  0.69333333]
#  [ 0.3         0.7       ]
#  [ 0.29333333  0.70666667]
#  [ 0.28666667  0.71333333]
#  [ 0.28        0.72      ]
#  [ 0.27333333  0.72666667]
#  [ 0.26666667  0.73333333]
#  [ 0.26        0.74      ]
#  [ 0.25333333  0.74666667]
#  [ 0.24666667  0.75333333]
#  [ 0.24        0.76      ]
#  [ 0.23333333  0.76666667]
#  [ 0.22666667  0.77333333]
#  [ 0.22        0.78      ]
#  [ 0.21333333  0.78666667]
#  [ 0.20666667  0.79333333]
#  [ 0.2         0.8       ]
#  [ 0.19333333  0.80666667]
#  [ 0.18666667  0.81333333]
#  [ 0.18        0.82      ]
#  [ 0.17333333  0.82666667]
#  [ 0.16666667  0.83333333]
#  [ 0.16        0.84      ]
#  [ 0.15333333  0.84666667]
#  [ 0.14666667  0.85333333]
#  [ 0.14        0.86      ]
#  [ 0.13333333  0.86666667]
#  [ 0.12666667  0.87333333]
#  [ 0.12        0.88      ]
#  [ 0.11333333  0.88666667]
#  [ 0.10666667  0.89333333]
#  [ 0.1         0.9       ]
#  [ 0.09333333  0.90666667]
#  [ 0.08666667  0.91333333]
#  [ 0.08        0.92      ]
#  [ 0.07333333  0.92666667]
#  [ 0.06666667  0.93333333]
#  [ 0.06        0.94      ]
#  [ 0.05333333  0.94666667]
#  [ 0.04666667  0.95333333]
#  [ 0.04        0.96      ]
#  [ 0.03333333  0.96666667]
#  [ 0.02666667  0.97333333]
#  [ 0.02        0.98      ]
#  [ 0.01333333  0.98666667]
#  [ 0.00666667  0.99333333]
#  [ 0.          1.        ]]
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy
# C:\Users\Alex\Anaconda\lib\site-packages\pythtb.py:1010: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if not (k_list==None):
# C:\Users\Alex\Anaconda\lib\site-packages\pythtb.py:855: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if k_input!=None:

# %% [markdown]
# _______________________

# %% [markdown]
# Giordano's Code

# %% [markdown]
# ________________________________________________________________________________________________________________________________________________________________________________________________________________________

# %%
N = 100
t = 100

def electron_placement(N,t, x_space, y_space):
    #M = number of electrons:
    #t = number of time steps

    a = 1    #lattice point spacing 

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    

    for i in range(N):
        b = np.random.randint(0, y_space)
        c = np.random.randint(0, x_space)  #to maintain randomness, keep N and the random integer bound equal
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = b * a * np.sqrt(3)
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
        electronarray[i] = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
    #print electronarray

    plt.plot(electronarray[:,0],electronarray[:,1], 'ro')
    plt.gca().set_aspect('equal')
    plt.grid()

    return electronarray
electronarray = electron_placement(N,t,25,25)

# %%
def motions(x,y,jtype,i):
    
    rand = np.random.random()
    new_pos = np.zeros(3)
    
    if (jtype % 2.0) == 0:
        if rand < 0.2:
            x_new = x + a
            y_new = y
            jtype_new = jtype + 1
        elif rand < 0.4:
            x_new = x - a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < 0.6:
            x_new = x - a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
    else:
        if rand < 0.2:
            x_new = x - a
            y_new = y
            jtype_new = jtype + 1
        elif rand < 0.4:
            x_new = x + a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < 0.6:
            x_new = x + a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
        
        if rand < 0.6:
            new_pos = electron_overlap_check(x_new, y_new, jtype_new, electronarray, i)
            x_new,y_new,jtype_new = new_pos[0], new_pos[1], new_pos[2]
    return np.asarray([x_new,y_new,jtype_new])

# %%
def electron_overlap_check(x_new, y_new, jtype_new, electronarray, i):
    x_array, y_array, jtype_array = electronarray[:, 0], electronarray[:, 1], electronarray[:,2]
    x, y, jtype = electronarray[i,0], electronarray[i,1], electronarray[i,2]
    length = len(x_array)
    electronarray_new = np.asarray([x_new, y_new, jtype_new])
    
    for j in np.arange(length-1):
        if i == j:
            j += 1
        if np.array_equiv(electronarray_new, electronarray[j]) == 1:
            #could add a counter that adds up the number of times an electron movement is rejected, then include that in the output
            new_pos = motions(x,y,jtype,i)
            x_new, y_new, jtype_new = new_pos[0], new_pos[1], new_pos[2]
            
    return np.asarray([x_new, y_new, jtype_new])

# %%
N = 100
t = 1000

def call_function(electronarray,t,N):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    
    for j in range(t):
        for i in range(N):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    
    return electrons
electrons = call_function(electronarray,t,N)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene' % N)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
fig.savefig('test2png.png', dpi=100)
# Out:
# (1000L, 100L, 3L)

# %%
#!/usr/bin/env python

# one dimensional chain

# Copyright under GNU General Public License 2010, 2012
# by Sinisa Coh and David Vanderbilt (see gpl-pythtb.txt)

from pythtb import * # import TB model class
import pylab as pl
# %pylab inline

# specify model
lat=[[1.0]]
orb=[[0.0]]
my_model=tb_model(1,1,lat,orb)
my_model.set_hop(-1., 0, 0, [1])

# solve model
path=[[-0.5],[0.5]]
kpts=k_path(path,100)
evals=my_model.solve_all(kpts)

# plot band structure
fig=pl.figure()
pl.plot(evals[0])
pl.title("1D chain band structure")
pl.xlabel("Path in k-space")
pl.ylabel("Band energy")
pl.savefig("simple_band.pdf")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from pythtb import *
# %pylab inline

# lattice vectors and orbital positions
lat=[[1.0, 0.0], [0.5, np.sqrt(3.0)/2.0]]
orb=[[1./3., 1./3.], [2./3., 2./3.]]
gra=tb_model(2, 2, lat, orb)

# define hopping between orbitals
gra.set_hop(-1.0, 0, 1, [ 0, 0])
gra.set_hop(-1.0, 1, 0, [ 1, 0])
gra.set_hop(-1.0, 1, 0, [ 0, 1])

# solve model on path in k-space
path=[[1.0, 0.0], [0.0, 1.0]]
kpts=k_path(path, 150)
evals=gra.solve_all(kpts)

# plot bandstructure
import matplotlib.pyplot as plt
plt.plot(evals[0, :])
plt.plot(evals[1, :])
plt.savefig("band.png")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#!/usr/bin/env python

# Toy graphene model

# Copyright under GNU General Public License 2010, 2012
# by Sinisa Coh and David Vanderbilt (see gpl-pythtb.txt)

from pythtb import * # import TB model class
import numpy as np
import pylab as pl
# %pylab inline

# define lattice vectors
lat=[[1.0,0.0],[0.5,np.sqrt(3.0)/2.0]]
# define coordinates of orbitals
orb=[[1./3.,1./3.],[2./3.,2./3.]]

# make two dimensional tight-binding graphene model
my_model=tb_model(2,2,lat,orb)

# set model parameters
delta=0.0 #must be zero to show dirac points/cones
t=-1.0

# set on-site energies
my_model.set_onsite([-delta,delta])
# set hoppings (one for each connected pair of orbitals)
# (amplitude, i, j, [lattice vector to cell containing j])
my_model.set_hop(t, 0, 1, [ 0, 0])
my_model.set_hop(t, 1, 0, [ 1, 0])
my_model.set_hop(t, 1, 0, [ 0, 1])

# print tight-binding model
my_model.display()

# generate list of k-points following some high-symmetry line in
# the k-space. Variable kpts here is just an array of k-points
path=[[1.0,0.0],[0.0,1.0]]
kpts=k_path(path,200)
print '---------------------------------------'
print 'report of k-point path'
print '---------------------------------------'
print 'Path runs over',len(kpts),'k-points connecting:'
for k in path:
    print k
print

print '---------------------------------------'
print 'starting calculation'
print '---------------------------------------'
print 'Calculating bands...'

# solve for eigenenergies of hamiltonian on
# the set of k-points from above
evals=my_model.solve_all(kpts)

# plotting of band structure
print 'Plotting bandstructure...'

# First make a figure object
fig=pl.figure()
# plot first band
pl.plot(evals[0])
# plot second band
pl.plot(evals[1])
# put title on top
pl.title("Graphene band structure")
pl.xlabel("Path in k-space")
pl.ylabel("Band energy")
# make an PDF figure of a plot
pl.savefig("graphene_band.pdf")

print 'Done.\n'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy
# C:\Users\Alex\Anaconda\lib\site-packages\pythtb.py:1010: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if not (k_list==None):
# report of tight-binding model
# ---------------------------------------
# k-space dimension           = 2
# r-space dimension           = 2
# number of spin components   = 1
# periodic directions         = [0, 1]
# number of orbitals          = 2
# number of electronic states = 2
# lattice vectors:
#  #  0  ===>  [     1.0 ,     0.0 ]
#  #  1  ===>  [     0.5 ,   0.866 ]
# positions of orbitals:
#  #  0  ===>  [  0.3333 ,  0.3333 ]
#  #  1  ===>  [  0.6667 ,  0.6667 ]
# site energies:
#  #  0  ===>      -0.0
#  #  1  ===>       0.0
# hoppings:
# <  0 | H |  1 + [  0 ,  0 ] >     ===>     -1.0 +     0.0 i
# <  1 | H |  0 + [  1 ,  0 ] >     ===>     -1.0 +     0.0 i
# <  1 | H |  0 + [  0 ,  1 ] >     ===>     -1.0 +     0.0 i
#
# ---------------------------------------
# report of k-point path
# ---------------------------------------
# Path runs over 201 k-points connecting:
# [1.0, 0.0]
# [0.0, 1.0]
#
# ---------------------------------------
# starting calculation
# ---------------------------------------
# Calculating bands...
# Plotting bandstructure...
# Done.
# C:\Users\Alex\Anaconda\lib\site-packages\pythtb.py:855: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if k_input!=None:

# %%
def electron_placement(N,t, x_space, y_space):
    #M = number of electrons:
    #t = number of time steps

    a = 1    #lattice point spacing 

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    

    for i in range(N):
        b = np.random.randint(0, y_space)
        c = np.random.randint(0, x_space)  #to maintain randomness, keep N and the random integer bound equal
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = b * a * np.sqrt(3)
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
        electronarray[i] = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
    #print electronarray

    plt.plot(electronarray[:,0],electronarray[:,1], 'ro')
    plt.gca().set_aspect('equal')
    plt.grid()

    return electronarray
electronarray = electron_placement(100,100,25,25)

# %%
import math
from decimal import *
getcontext().prec = 8

def prob(x,y,T,jtype):
    
    #Use Boltzmann distribution
    #partition function = 1/((Number of unocuppied adjacent sites)*exp(-Ehop/kT)+ exp(-Estay/kT))
    #Occupied E's equal infinity due to Coulomb repulsion and Pauli Exclusion --> probabilities equal zero
    #roof of rand equals prob 1 + prob 2 + prob 3 + standing energy
    #if roof =/= 1: multiply random number by (roof) to scale it down (will implement this later)
    
    if (jtype % 2.0) == 0:
        x1 = x + a
        y1 = y
        
        x2 = x - a/2.0
        y2 = y + np.sqrt(3.0)*a/2.0
        
        x3 = x - a/2.0
        y3 = y - np.sqrt(3.0)*a/2.0
    else:
        x1 = x - a
        y1 = y
        
        x2 = x + a/2.0
        y2 = y - np.sqrt(3.0)*a/2.0
        
        x3 = x + a/2.0
        y3 = y + np.sqrt(3.0)*a/2.0
        
    hop1 = x1,y1,jtype
    hop2 = x2,y2,jtype
    hop3 = x3,y3,jtype
    
    counter = 0
    probval1 = 1
    probval2 = 1
    probval3 = 1
    probvalstay = 1
    
    for j in range(len(electronarray)):
        if np.array_equiv(hop1, electronarray[j]) == 1:
            counter += 1
            probval1 = 0 #removes probability of hopping to site if occupied
        if np.array_equiv(hop2, electronarray[j]) == 1:
            counter += 1
            probval2 = 0 #"                                                 "
        if np.array_equiv(hop3, electronarray[j]) == 1:
            counter += 1
            probval3 = 0 #"                                                 "
            
    sites = 3 - counter #(counter = number of occupied adjacent sites)
    k = 8.6 * 10e-5
    
    Ehop = 38.1212 #eV, equals atomic energy (calculated via Rydeberg Formula) plus hopping energy (approx. 2.6 eV)
    Estay = 35.52 #eV, atomic energy calculated using Rydbergs formula for the valence orbital of Carbon
    
    b = (-Ehop/(1.0*k*T))
    c = (-Estay/(1.0*k*T))
    
    probvalhop = (Decimal(b).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp())) #Used decimal module for increased precision
    probvalstay = (Decimal(c).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    
    probvalhop = float(probvalhop)
    probvalstay = float(probvalstay)
    
    if probval1 == 1: #Checks if site is unoccupied. If so, changes probability from 1 (arbitrary) to the calculated value
        probval1 = probvalhop
    if probval2 == 1:
        probval2 = probvalhop
    if probval3 == 1:
        probval3 = probvalhop
        
    z = [probval1,probval2,probval3,probvalstay]
    
    
    return z

# %%
def motions(x,y,jtype,i,T):
    
    rand = np.random.random()
    new_pos = np.zeros(3)
    
    z = prob(x,y,T,jtype)
    
    if (jtype % 2.0) == 0:
        if rand < z[0]:
            x_new = x + a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x - a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x - a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
    else:
        if rand < z[0]:
            x_new = x - a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x + a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x + a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
        
        if rand < (z[0]+z[1]+z[2]):
            new_pos = electron_overlap_check(x_new, y_new, jtype_new, electronarray, i)
            x_new,y_new,jtype_new = new_pos[0], new_pos[1], new_pos[2]
    return np.asarray([x_new,y_new,jtype_new])

# %%
def electron_overlap_check(x_new, y_new, jtype_new, electronarray, i): #Not used later, since the prob function adequately 
                                                                       #prevents overlap
        
    x_array, y_array, jtype_array = electronarray[:, 0], electronarray[:, 1], electronarray[:,2]
    x, y, jtype = electronarray[i,0], electronarray[i,1], electronarray[i,2]
    length = len(x_array)
    electronarray_new = np.asarray([x_new, y_new, jtype_new])
    
    for j in np.arange(length-1):
        if i == j:
            j += 1
        if np.array_equiv(electronarray_new, electronarray[j]) == 1:
            new_pos = motions(x,y,jtype,i,T)
            x_new, y_new, jtype_new = new_pos[0], new_pos[1], new_pos[2]
            
    return np.asarray([x_new, y_new, jtype_new])

# %% [markdown]
# ____________________________________________

# %% [markdown]
# Below we use the code created so far, and string it all together in order to try to create a temperature dependent model of
# electron hopping.

# %% [markdown]
# ____________________________________________

# %%
from decimal import *
getcontext().prec = 8
N = 100
t = 100
T = 3000
a = 1

def call_function(electronarray,t,N,T):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    
    for j in range(t):
        for i in range(N):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    
    return electrons
electrons = call_function(electronarray,t,N,T)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene at %d Kelvin' % (N, T))
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
fig.savefig('test2png.png', dpi=100)
# Out:
# (100L, 100L, 3L)

# %%
from decimal import *
getcontext().prec = 8
N = 100
t = 100
T = 1500
a = 1

def call_function(electronarray,t,N,T):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    
    for j in range(t):
        for i in range(N):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    
    return electrons
electrons = call_function(electronarray,t,N,T)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene at %d Kelvin' % (N, T))
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
fig.savefig('test2png.png', dpi=100)
# Out:
# (100L, 100L, 3L)

# %%
from decimal import *
getcontext().prec = 8
N = 100
t = 100
T = 900
a = 1

def call_function(electronarray,t,N,T):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    
    for j in range(t):
        for i in range(N):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    
    return electrons
electrons = call_function(electronarray,t,N,T)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene at %d Kelvin' % (N, T))
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
fig.savefig('test2png.png', dpi=100)
# Out:
# (100L, 100L, 3L)

# %%
"""Final Project: Giordano Pugliese's contribution
Nearest neighbor interactions only(first approximation of tightbinding model)"""

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def electron_placement():
    N = 100 #number of electrons: this should or could be a function of temperature
    #N = input('How many electrons would you like to place? ')
    t = 100 #number of time steps
    #t = input('How many time steps? ')

    x_space = input('what would you like the x dimension of the initial electron distribution to be? ')#keep these on the same order as N
    y_space = input('what would you like the y dimension of the initial electron distribution to be? ')

    a = 1    #lattice point spacing: can be changed by simply multiplying by lattice constant,same for the random integers b and c

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    b = np.random.randint(0, y_space)

    for i in range(N):
        c = np.random.randint(x_space)  #to maintain randomness, keep N and the random integer bound equal
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = (np.random.randint(y_space) * a * np.sqrt(3))
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
        electronarray[i] = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
    #print electronarray

    plt.plot(electronarray[:,0],electronarray[:,1], 'ro')
    plt.gca().set_aspect('equal')
    plt.grid()

    return electronarray
electronarray = electron_placement()
# Out:
# what would you like the x dimension of the initial electron distribution to be? 25
# what would you like the y dimension of the initial electron distribution to be? 25

# %%
def motions(x,y,jtype,i):
    
    rand = np.random.random()
    new_pos = np.zeros(3)
    
    if (jtype % 2.0) == 0:
        if rand < 0.2:
            x_new = x + a
            y_new = y
            jtype_new = jtype + 1
        elif rand < 0.4:
            x_new = x - a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < 0.6:
            x_new = x - a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
    else:
        if rand < 0.2:
            x_new = x - a
            y_new = y
            jtype_new = jtype + 1
        elif rand < 0.4:
            x_new = x + a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < 0.6:
            x_new = x + a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
        
        if rand < 0.6:
            new_pos = electron_overlap_check(x_new, y_new, jtype_new, electronarray, i)
            x_new,y_new,jtype_new = new_pos[0], new_pos[1], new_pos[2]
    return np.asarray([x_new,y_new,jtype_new])

# %%
def electron_overlap_check(x_new, y_new, jtype_new, electronarray, i):
    x_array, y_array, jtype_array = electronarray[:, 0], electronarray[:, 1], electronarray[:,2]
    x, y, jtype = electronarray[i,0], electronarray[i,1], electronarray[i,2]
    length = len(x_array)
    electronarray_new = np.asarray([x_new, y_new, jtype_new])
    
    for j in np.arange(length-1):
        if i == j:
            j += 1
        if np.array_equiv(electronarray_new, electronarray[j]) == 1:
            #could add a counter that adds up the number of times an electron movement is rejected, then include that in the output
            new_pos = motions(x,y,jtype,i)
            x_new, y_new, jtype_new = new_pos[0], new_pos[1], new_pos[2]
            
    return np.asarray([x_new, y_new, jtype_new])

# %%
def call_function(electronarray,t,N):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    
    for j in range(t):
        for i in range(N):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    
    return electrons
electrons = call_function(electronarray,t,N)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene' % N)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
fig.savefig('test2png.png', dpi=100)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-413e2c8fcbac> in <module>()
#      17
#      18     return electrons
# ---> 19 electrons = call_function(electronarray,t,N)
#      20
#      21 for i in xrange(N):
#
# <ipython-input-32-413e2c8fcbac> in call_function(electronarray, t, N)
#       7     for j in range(t):
#       8         for i in range(N):
# ----> 9             new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i)
#      10             electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
#      11         #print electronarray
#
# TypeError: motions() takes exactly 5 arguments (4 given)

# %%
"""code from another source"""

# %%
#!/usr/bin/env python

# one dimensional chain

# Copyright under GNU General Public License 2010, 2012
# by Sinisa Coh and David Vanderbilt (see gpl-pythtb.txt)

from pythtb import * # import TB model class
import pylab as pl
# %pylab inline

# specify model
lat=[[1.0]]
orb=[[0.0]]
my_model=tb_model(1,1,lat,orb)
my_model.set_hop(-1., 0, 0, [1])

# solve model
path=[[-0.5],[0.5]]
kpts=k_path(path,100)
evals=my_model.solve_all(kpts)

# plot band structure
fig=pl.figure()
pl.plot(evals[0])
pl.title("1D chain band structure")
pl.xlabel("Path in k-space")
pl.ylabel("Band energy")
pl.savefig("simple_band.pdf")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
from pythtb import *
# %pylab inline

# lattice vectors and orbital positions
lat=[[1.0, 0.0], [0.5, np.sqrt(3.0)/2.0]]
orb=[[1./3., 1./3.], [2./3., 2./3.]]
gra=tb_model(2, 2, lat, orb)

# define hopping between orbitals
gra.set_hop(-1.0, 0, 1, [ 0, 0])
gra.set_hop(-1.0, 1, 0, [ 1, 0])
gra.set_hop(-1.0, 1, 0, [ 0, 1])

# solve model on path in k-space
path=[[1.0, 0.0], [0.0, 1.0]]
kpts=k_path(path, 150)
evals=gra.solve_all(kpts)

# plot bandstructure
import matplotlib.pyplot as plt
plt.plot(evals[0, :])
plt.plot(evals[1, :])
plt.savefig("band.png")

# %%
#!/usr/bin/env python

# Toy graphene model

# Copyright under GNU General Public License 2010, 2012
# by Sinisa Coh and David Vanderbilt (see gpl-pythtb.txt)

from pythtb import * # import TB model class
import numpy as np
import pylab as pl
# %pylab inline

# define lattice vectors
lat=[[1.0,0.0],[0.5,np.sqrt(3.0)/2.0]]
# define coordinates of orbitals
orb=[[1./3.,1./3.],[2./3.,2./3.]]

# make two dimensional tight-binding graphene model
my_model=tb_model(2,2,lat,orb)

# set model parameters
delta=0.0 #must be zero to show dirac points/cones
t=-1.0

# set on-site energies
my_model.set_onsite([-delta,delta])
# set hoppings (one for each connected pair of orbitals)
# (amplitude, i, j, [lattice vector to cell containing j])
my_model.set_hop(t, 0, 1, [ 0, 0])
my_model.set_hop(t, 1, 0, [ 1, 0])
my_model.set_hop(t, 1, 0, [ 0, 1])

# print tight-binding model
my_model.display()

# generate list of k-points following some high-symmetry line in
# the k-space. Variable kpts here is just an array of k-points
path=[[1.0,0.0],[0.0,1.0]]
kpts=k_path(path,200)
print '---------------------------------------'
print 'report of k-point path'
print '---------------------------------------'
print 'Path runs over',len(kpts),'k-points connecting:'
for k in path:
    print k
print

print '---------------------------------------'
print 'starting calculation'
print '---------------------------------------'
print 'Calculating bands...'

# solve for eigenenergies of hamiltonian on
# the set of k-points from above
evals=my_model.solve_all(kpts)

# plotting of band structure
print 'Plotting bandstructure...'

# First make a figure object
fig=pl.figure()
# plot first band
pl.plot(evals[0])
# plot second band
pl.plot(evals[1])
# put title on top
pl.title("Graphene band structure")
pl.xlabel("Path in k-space")
pl.ylabel("Band energy")
# make an PDF figure of a plot
pl.savefig("graphene_band.pdf")

print 'Done.\n'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# ---------------------------------------
# report of tight-binding model
# ---------------------------------------
# k-space dimension           = 2
# r-space dimension           = 2
# number of spin components   = 1
# periodic directions         = [0, 1]
# number of orbitals          = 2
# number of electronic states = 2
# lattice vectors:
#  #  0  ===>  [     1.0 ,     0.0 ]
#  #  1  ===>  [     0.5 ,   0.866 ]
# positions of orbitals:
#  #  0  ===>  [  0.3333 ,  0.3333 ]
#  #  1  ===>  [  0.6667 ,  0.6667 ]
# site energies:
#  #  0  ===>      -0.0
#  #  1  ===>       0.0
# hoppings:
# <  0 | H |  1 + [  0 ,  0 ] >     ===>     -1.0 +     0.0 i
# <  1 | H |  0 + [  1 ,  0 ] >     ===>     -1.0 +     0.0 i
# <  1 | H |  0 + [  0 ,  1 ] >     ===>     -1.0 +     0.0 i
#
# ---------------------------------------
# report of k-point path
# ---------------------------------------
# Path runs over 201 k-points connecting:
# [1.0, 0.0]
# [0.0, 1.0]
#
# ---------------------------------------
# starting calculation
# ---------------------------------------
# Calculating bands...
# Plotting bandstructure...
# Done.
# WARNING: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-4176ac997426> in <module>()
#      30
#      31     return electrons
# ---> 32 electrons = call_function(electronarray,t,N,T)
#      33
#      34 for i in xrange(N):
#
# <ipython-input-18-4176ac997426> in call_function(electronarray, t, N, T)
#      20     for j in range(t):
#      21         for i in range(N):
# ---> 22             new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
#      23             electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
#      24         #print electronarray
#
# IndexError: too many indices for array

# %%
N = 500
T = 900
t = 200

def electron_placement(N,t, x_space, y_space):
    #M = number of electrons:
    #t = number of time steps

    a = 1    #lattice point spacing 

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    

    for i in range(N):
        b = np.random.randint(0, y_space)
        c = np.random.randint(0, x_space)  #to maintain randomness, keep N and the random integer bound equal
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = b * a * np.sqrt(3)
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
        electronarray[i] = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
    #print electronarray

    plt.plot(electronarray[:,0],electronarray[:,1], 'ro')
    plt.gca().set_aspect('equal')
    plt.grid()

    return electronarray
electronarray = electron_placement(N,t,25,25)

# %%
from decimal import *
getcontext().prec = 8

def prob(x,y,T,jtype): #hop --> state = 1, stay --> state = 0
    if (jtype % 2.0) == 0:
        x1 = x + a
        y1 = y
        
        x2 = x - a/2.0
        y2 = y + np.sqrt(3.0)*a/2.0
        
        x3 = x - a/2.0
        y3 = y - np.sqrt(3.0)*a/2.0
    else:
        x1 = x - a
        y1 = y
        
        x2 = x + a/2.0
        y2 = y - np.sqrt(3.0)*a/2.0
        
        x3 = x + a/2.0
        y3 = y + np.sqrt(3.0)*a/2.0
        
    hop1 = x1,y1,jtype
    hop2 = x2,y2,jtype
    hop3 = x3,y3,jtype
    
    counter = 0
    probval1 = 1
    probval2 = 1
    probval3 = 1
    probvalstay = 1
    
    for j in range(len(electronarray)):
        if np.array_equiv(hop1, electronarray[j]) == 1:
            counter += 1
            probval1 = 0
        if np.array_equiv(hop2, electronarray[j]) == 1:
            counter += 1
            probval2 = 0
        if np.array_equiv(hop3, electronarray[j]) == 1:
            counter += 1
            probval3 = 0
            
    sites = 3 - counter
    k = 8.6 * 10e-5
    
    Ehop = 38.1212 #eV, equals atomic energy (calculated via Rydeberg Formula) plus hopping energy (approx. 2.6 eV)
    Estay = 35.52 #eV, atomic energy calculated using Rydbergs formula
    
    b = (-Ehop/(1.0*k*T))
    c = (-Estay/(1.0*k*T))
    
    probvalhop = (Decimal(b).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    probvalstay = (Decimal(c).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    
    probvalhop = float(probvalhop)
    probvalstay = float(probvalstay)
    
    if probval1 == 1:
        probval1 = probvalhop
    if probval2 == 1:
        probval2 = probvalhop
    if probval3 == 1:
        probval3 = probvalhop
        
    z = [probval1,probval2,probval3,probvalstay]
    
    
    return z

# %%
def motions(x,y,jtype,i,T):
    
    rand = np.random.random()
    new_pos = np.zeros(3)
    
    z = prob(x,y,T,jtype)
    
    if (jtype % 2.0) == 0:
        if rand < z[0]:
            x_new = x + a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x - a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x - a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
    else:
        if rand < z[0]:
            x_new = x - a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x + a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x + a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
        
        if rand < (z[0]+z[1]+z[2]):
            new_pos = electron_overlap_check(x_new, y_new, jtype_new, electronarray, i)
            x_new,y_new,jtype_new = new_pos[0], new_pos[1], new_pos[2]
    return np.asarray([x_new,y_new,jtype_new])

# %%
def electron_overlap_check(x_new, y_new, jtype_new, electronarray, i):
    x_array, y_array, jtype_array = electronarray[:, 0], electronarray[:, 1], electronarray[:,2]
    x, y, jtype = electronarray[i,0], electronarray[i,1], electronarray[i,2]
    length = len(x_array)
    electronarray_new = np.asarray([x_new, y_new, jtype_new])
    
    for j in np.arange(length-1):
        if i == j:
            j += 1
        if np.array_equiv(electronarray_new, electronarray[j]) == 1:
            new_pos = motions(x,y,jtype,i,T)
            x_new, y_new, jtype_new = new_pos[0], new_pos[1], new_pos[2]
            
    return np.asarray([x_new, y_new, jtype_new])

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

T = 30000
N = 100
a = 1
t = 100
electronarray = np.arange(0,N+1)
locarrayx = np.zeros(N)
locarrayy = np.zeros(N)
jtype = np.zeros(N)
x_space = 100
y_space = 100

# %%
#Updated initialization function preventing electrons from initially being placed on top of each other by accident

def electron_placement(N,t,x_space,y_space):
    print("the value of N must be less than the total number of lattice sites or this function will run forever. Try to keep N less than the product of the x and y space")

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    b = np.random.randint(0, y_space)
    
    counter = 0
    for i in range(N):
        c = np.random.randint(x_space)
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = (np.random.randint(y_space) * a * np.sqrt(3))
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
            
        electronarray_new = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
        
        j = -1
        for k in np.arange(0,N-1):
            j += 1
            if i == j:
                j += 1
            #print j
            if np.allclose(electronarray_new, np.asarray(electronarray[j])) == 1:
                while np.allclose(electronarray_new, np.asarray(electronarray[j])) == 1:
                    counter += 1
                    c = np.random.randint(x_space)
                    locarrayx[i] = c * 3.*a / 2
                    locarrayx += a
                    b = (np.random.randint(y_space) * a * np.sqrt(3))
                    if c % 2 == 0:
                        locarrayy[i] =  b
                    else:
                        locarrayy[i] = b + a * np.sqrt(3) / 2.
                    electronarray_new = np.asarray([locarrayx[i],locarrayy[i],jtype[i]])
                        
        electronarray[i] = np.asarray(electronarray_new)
    i = 0
    
    #print 'counter = ', (counter)
    
    plt.plot(electronarray[:,0], electronarray[:,1], 'ro')
    #plt.gca().set_aspect('equal')
    plt.grid()
    fig = plt.gcf()
    fig.set_size_inches(10, 10, forward=True)

    return electronarray
electronarray = electron_placement(N,t,x_space,y_space)
# Out:
# the value of N must be less than the total number of lattice sites or this function will run forever. Try to keep N less than the product of the x and y space
# counter =  1

# %%
#Testing electron motion simulation with updated initialization

from decimal import *
getcontext().prec = 8


def call_function(electronarray,t,N,T):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray = np.zeros([N,3])
    electronarray_old = electronarray
    
    for j in range(t):
        for i in range(N-1):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    
    return electrons
electrons = call_function(electronarray,t,N,T)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene' % N)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
#fig.savefig('test2png.png', dpi=100)
# Out:
# (100L, 100L, 3L)

# %%
for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene' % N)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
print(electrons[199,:,2])
# Out:
# [ 24.  12.  10.  18.  15.  12.  21.  14.  15.  24.  19.  13.  19.  19.  19.
#   10.  21.  16.  21.  21.  15.  18.  31.  20.  17.  19.  24.  21.  24.  17.
#   26.  19.  16.  11.  15.  21.  20.  18.  19.  25.  17.  16.  16.  26.  21.
#   27.  13.  15.  17.  16.  22.  24.  10.  16.  23.  21.  20.  16.  22.  23.
#   16.  20.  17.  15.  27.  22.  21.  22.  16.  19.  19.  13.  13.  21.  11.
#   16.  24.  22.  21.  19.  22.   8.  19.  22.  25.  20.  19.  21.  21.  22.
#   18.  26.  26.  21.  18.  14.  27.  11.  18.  19.  29.  26.  15.  18.  17.
#   28.  16.  21.  18.  20.  19.  26.  19.  18.  18.  19.  18.  21.  23.  20.
#   17.  25.  16.  19.  11.  13.  21.  16.  22.  16.  12.  20.  23.  15.  19.
#   22.  24.  22.  20.  13.  24.  19.  29.  17.  27.  22.  14.  14.  16.  15.
#   17.  15.  21.  24.  15.  15.  21.  19.  19.  23.  18.  19.  18.  13.  24.
#   23.  20.  16.  16.  17.  17.  17.  15.  23.  15.  19.  12.  20.  18.   9.
#   23.  20.  26.  17.  25.  18.  16.  15.  22.  19.  22.  17.  27.  25.  20.
#   18.  24.  23.  19.  26.  25.  13.  20.  13.  24.  19.  23.  24.  10.  21.
#   17.  21.  18.  21.  20.  27.  18.  16.  22.  22.  26.  19.  18.  17.  18.
#   11.  20.  21.  20.  25.  23.  22.  26.  16.  27.  26.  22.  20.  15.  20.
#   17.  20.  21.  23.  21.  21.  25.  17.  20.  21.  16.  17.  19.  22.  19.
#   13.  19.  29.  25.  14.  17.  20.  24.  14.  16.  17.  22.  21.  20.   9.
#   27.  24.  20.  19.  25.  21.  18.  17.  21.  18.  16.  26.  23.  17.  18.
#   17.  25.  15.  13.  21.  18.  12.  26.  17.  16.  19.  17.  18.  23.  19.
#   21.  15.  22.  21.  21.  28.  23.  20.  17.  20.  14.  22.  25.  24.  15.
#   22.  18.  20.  30.  23.  22.  14.  22.  21.  20.  15.  22.  15.  21.  21.
#   28.  15.  15.  21.  16.  20.  14.  18.  15.  19.  15.  18.  21.  18.  12.
#   16.  18.  24.  14.  19.  17.  12.  20.  21.  10.  16.  13.  25.  19.  19.
#   18.  18.  23.  20.  18.  17.  22.  16.  14.  18.  21.  25.  15.  24.  25.
#   17.  18.  15.  21.  29.  20.  18.  16.  14.  11.  21.  18.  21.  28.  22.
#   15.  17.  17.  17.  18.  18.  16.  24.  17.  16.  20.  19.  24.  16.  25.
#   23.  19.  14.  20.  20.  22.  19.  18.  21.  19.  16.  15.  23.  16.  25.
#   22.  18.  15.  21.  20.  24.  24.  19.  12.  18.  20.  15.  26.  10.  17.
#   17.  22.  10.  23.  14.  24.  17.  12.  17.  18.  18.  21.  13.  15.  14.
#   19.  19.  23.  15.  14.  15.  25.  16.  27.  17.  19.  23.  20.  16.  19.
#   23.  19.  23.  15.  18.  17.  20.  14.  16.  13.  17.  19.   9.  23.  15.
#   11.  18.  21.  14.  18.  13.  15.  27.  20.  26.  13.  22.  18.  27.  27.
#   15.  13.  14.  19.   0.]

# %%
plt.imshow(electrons) #Toying around (looks cool! May print out and hang on my wall)

# %%
N = 100
t = 100
T = 3000
q = np.zeros([N,3])
q = electron_placement(N,t,x_space,y_space)
for i in range(10,T,100):
    T = i
    w = call_function(q,t,N,T)
    print(np.average(w[-1,:,2])) #Tried to print out average end hop count (jtype for each electron at end of simulation)
# Out:
# the value of N must be less than the total number of lattice sites or this function will run forever. Try to keep N less than the product of the x and y space
# counter =  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9d26af2bf875> in <module>()
#       6 for i in range(10,T,100):
#       7     T = i
# ----> 8     w = call_function(q,t,N,T)
#       9     print(np.average(w[-1,:,2]))
#
# <ipython-input-18-5a4c4b4918b3> in call_function(electronarray, t, N, T)
#      12     for j in range(t):
#      13         for i in range(N-1):
# ---> 14             new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
#      15             electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
#      16         #print electronarray
#
# <ipython-input-15-83a241421593> in motions(x, y, jtype, i, T)
#       4     new_pos = np.zeros(3)
#       5
# ----> 6     z = prob(x,y,T,jtype)
#       7
#       8     if (jtype % 2.0) == 0:
#
# <ipython-input-17-0851dd55a861> in prob(x, y, T, jtype)
#      33
#      34     for j in range(len(electronarray)):
# ---> 35         if np.array_equiv(hop1, electronarray[j]) == 1:
#      36             counter += 1
#      37             probval1 = 0
#
# KeyboardInterrupt:

# %%
help(range)
# Out:
# Help on built-in function range in module __builtin__:
#
# range(...)
#     range(stop) -> list of integers
#     range(start, stop[, step]) -> list of integers
#
#     Return a list containing an arithmetic progression of integers.
#     range(i, j) returns [i, i+1, i+2, ..., j-1]; start (!) defaults to 0.
#     When step is given, it specifies the increment (or decrement).
#     For example, range(4) returns [0, 1, 2, 3].  The end point is omitted!
#     These are exactly the valid indices for a list of 4 elements.

# %%
#Put all functions in a row in a single cell for ease of running (removes need to run separate cells in order, removes confusion
#from carried over memory from cells previously ran)

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from decimal import *
getcontext().prec = 13

T = 12000
N = 100
a = 1
t = 100
electronarray = np.arange(0,N+1)
locarrayx = np.zeros(N)
locarrayy = np.zeros(N)
jtype = np.zeros(N)
x_space = 100
y_space = 100

def electron_placement(N,t,x_space,y_space):
    #print("the value of N must be less than the total number of lattice sites or this function will run forever. 
    #Try to keep N less than the product of the x and y space")

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    b = np.random.randint(0, y_space)
    
    counter = 0
    for i in range(N):
        c = np.random.randint(x_space)
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = (np.random.randint(y_space) * a * np.sqrt(3))
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
            
        electronarray_new = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
        
        j = -1
        for k in np.arange(0,N-1):
            j += 1
            if i == j:
                j += 1
            #print j
            if np.allclose(electronarray_new, np.asarray(electronarray[j])) == 1:
                while np.allclose(electronarray_new, np.asarray(electronarray[j])) == 1:
                    counter += 1
                    c = np.random.randint(x_space)
                    locarrayx[i] = c * 3.*a / 2
                    locarrayx += a
                    b = (np.random.randint(y_space) * a * np.sqrt(3))
                    if c % 2 == 0:
                        locarrayy[i] =  b
                    else:
                        locarrayy[i] = b + a * np.sqrt(3) / 2.
                    electronarray_new = np.asarray([locarrayx[i],locarrayy[i],jtype[i]])
                        
        electronarray[i] = np.asarray(electronarray_new)
    i = 0
    
    
    #plt.plot(electronarray[:,0], electronarray[:,1], 'ro')
    #plt.gca().set_aspect('equal')
    plt.grid()
    fig = plt.gcf()
    fig.set_size_inches(10, 10, forward=True)

    return electronarray
electronarray = electron_placement(N,t,x_space,y_space)

def electron_overlap_check(x_new, y_new, jtype_new, electronarray, i):
    x_array, y_array, jtype_array = electronarray[:, 0], electronarray[:, 1], electronarray[:,2]
    x, y, jtype = electronarray[i,0], electronarray[i,1], electronarray[i,2]
    length = len(x_array)
    electronarray_new = np.asarray([x_new, y_new, jtype_new])
    
    for j in np.arange(length-1):
        if i == j:
            j += 1
        if np.array_equiv(electronarray_new, electronarray[j]) == 1:
            new_pos = motions(x,y,jtype,i,T)
            x_new, y_new, jtype_new = new_pos[0], new_pos[1], new_pos[2]
            
    return np.asarray([x_new, y_new, jtype_new])

def prob(x,y,T,jtype): 
    if (jtype % 2.0) == 0:
        x1 = x + a
        y1 = y
        
        x2 = x - a/2.0
        y2 = y + np.sqrt(3.0)*a/2.0
        
        x3 = x - a/2.0
        y3 = y - np.sqrt(3.0)*a/2.0
    else:
        x1 = x - a
        y1 = y
        
        x2 = x + a/2.0
        y2 = y - np.sqrt(3.0)*a/2.0
        
        x3 = x + a/2.0
        y3 = y + np.sqrt(3.0)*a/2.0
        
    hop1 = x1,y1,jtype
    hop2 = x2,y2,jtype
    hop3 = x3,y3,jtype
    
    counter = 0
    probval1 = 1
    probval2 = 1
    probval3 = 1
    probvalstay = 1
    
    for j in range(len(electronarray)):
        if np.array_equiv(hop1, electronarray[j]) == 1:
            counter += 1
            probval1 = 0
        if np.array_equiv(hop2, electronarray[j]) == 1:
            counter += 1
            probval2 = 0
        if np.array_equiv(hop3, electronarray[j]) == 1:
            counter += 1
            probval3 = 0
            
    sites = 3 - counter
    k = 8.6 * 10e-5
    
    Ehop = 38.1212 #eV, equals atomic energy (calculated via Rydeberg Formula) plus hopping energy (approx. 2.6 eV)
    Estay = 35.52 #eV, atomic energy calculated using Rydbergs formula
    
    b = (-Ehop/(1.0*k*T))
    c = (-Estay/(1.0*k*T))
    
    probvalhop = (Decimal(b).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    probvalstay = (Decimal(c).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    
    probvalhop = float(probvalhop)
    probvalstay = float(probvalstay)
    
    if probval1 == 1:
        probval1 = probvalhop
    if probval2 == 1:
        probval2 = probvalhop
    if probval3 == 1:
        probval3 = probvalhop
        
    z = [probval1,probval2,probval3,probvalstay]
    
    
    return z

def motions(x,y,jtype,i,T):
    
    rand = np.random.random()
    new_pos = np.zeros(3)
    
    z = prob(x,y,T,jtype)
    rand *= np.sum(z)
    if (jtype % 2.0) == 0:
        if rand < z[0]:
            x_new = x + a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x - a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x - a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
    else:
        if rand < z[0]:
            x_new = x - a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x + a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x + a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
        
        
    return np.asarray([x_new,y_new,jtype_new])

def call_function(electronarray,t,N,T):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    j_avg = []
    for j in range(t):
        for i in range(N-1):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
            if j == (t-1):
                j_avg.append(new_electron[2])
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    j_avg = np.average(j_avg)
    print('average j is', j_avg)
    return electrons, j_avg
electrons,j_avg = call_function(electronarray,t,N,T)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene' % N)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
#fig.savefig('test2png.png', dpi=100)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 146
# (100L, 100L, 3L)
# ('average j is', 70.262626262626256)

# %% [markdown]
# Above we see how the appearance of the end plot of our electron motion simulation can depend heavily on the x_space and y_space
# values chosen, as it causes the electrons to be either much more closely confined or much more spread out.

# %%
#Here we begin to sweep the temperature to show the relation between T and hopping probability 

T = 30000
q = np.zeros([N,3])

val = ((T-100)/100)
temp = []
r = []
g = []
for i in range(100,T+3100,3000):
    q = electron_placement(N,t,x_space,y_space)
    T = i
    print('the temperature is %d' % T)
    temp.append(T)
    w,o = call_function(q,t,N,T)
    o = 1.0 * o / t
    #o = j_avg
    g.append(o)
    print('the average hopping probability at temperature %f is %f' % (T, o))
    print(o)
    electronarray = np.zeros([N,3])
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
plt.plot(temp,g)
plt.title('hopping probability versus temperature')
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 137
# the temperature is 100
# (100L, 100L, 3L)
# ('average j is', 0.0)
# the average hopping probability at temperature 100.000000 is 0.000000
# 0.0
# the temperature is 3100
# (100L, 100L, 3L)
# ('average j is', 52.898989898989896)
# the average hopping probability at temperature 3100.000000 is 0.528990
# 0.52898989899
# the temperature is 6100
# (100L, 100L, 3L)
# ('average j is', 64.939393939393938)
# the average hopping probability at temperature 6100.000000 is 0.649394
# 0.649393939394
# the temperature is 9100
# (100L, 100L, 3L)
# ('average j is', 68.242424242424249)
# the average hopping probability at temperature 9100.000000 is 0.682424
# 0.682424242424
# the temperature is 12100
# (100L, 100L, 3L)
# ('average j is', 70.777777777777771)
# the average hopping probability at temperature 12100.000000 is 0.707778
# 0.707777777778
# the temperature is 15100
# (100L, 100L, 3L)
# ('average j is', 71.060606060606062)
# the average hopping probability at temperature 15100.000000 is 0.710606
# 0.710606060606
# the temperature is 18100
# (100L, 100L, 3L)
# ('average j is', 71.444444444444443)
# the average hopping probability at temperature 18100.000000 is 0.714444
# 0.714444444444
# the temperature is 21100
# (100L, 100L, 3L)
# ('average j is', 71.909090909090907)
# the average hopping probability at temperature 21100.000000 is 0.719091
# 0.719090909091
# the temperature is 24100
# (100L, 100L, 3L)
# ('average j is', 71.979797979797979)
# the average hopping probability at temperature 24100.000000 is 0.719798
# 0.719797979798
# the temperature is 27100
# (100L, 100L, 3L)
# ('average j is', 72.878787878787875)
# the average hopping probability at temperature 27100.000000 is 0.728788
# 0.728787878788
# the temperature is 30100
# (100L, 100L, 3L)
# ('average j is', 72.828282828282823)
# the average hopping probability at temperature 30100.000000 is 0.728283
# 0.728282828283

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

T = 3000
N = 100
a = 1
t = 100
electronarray = np.arange(0,N+1)
locarrayx = np.zeros(N)
locarrayy = np.zeros(N)
jtype = np.zeros(N)
x_space = 100
y_space = 100

# %%
#Make electron motion simulation printig the average number of hops per electron for given number of time steps

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from decimal import *
getcontext().prec = 13

T = 3000
N = 100
a = 1
t = 100
electronarray = np.arange(0,N+1)
locarrayx = np.zeros(N)
locarrayy = np.zeros(N)
jtype = np.zeros(N)
x_space = 100
y_space = 100

def electron_placement(N,t,x_space,y_space):
    #print("the value of N must be less than the total number of lattice sites or this function will run forever. Try to keep N less than the product of the x and y space")

    electronarray = np.zeros([N,3]) #array that will contain the positions of each electron
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
    b = np.random.randint(0, y_space)
    
    counter = 0
    for i in range(N):
        c = np.random.randint(x_space)
        locarrayx[i] = c * 3.*a / 2
        locarrayx += a
        b = (np.random.randint(y_space) * a * np.sqrt(3))
        if c % 2 == 0:
            locarrayy[i] =  b
        else:
            locarrayy[i] = b + a * np.sqrt(3) / 2.
            
        electronarray_new = np.asarray([locarrayx[i],locarrayy[i],jtype[i]]) #setting the electron positions
        
        j = -1
        for k in np.arange(0,N-1):
            j += 1
            if i == j:
                j += 1
            #print j
            if np.allclose(electronarray_new, np.asarray(electronarray[j])) == 1:
                while np.allclose(electronarray_new, np.asarray(electronarray[j])) == 1:
                    counter += 1
                    c = np.random.randint(x_space)
                    locarrayx[i] = c * 3.*a / 2
                    locarrayx += a
                    b = (np.random.randint(y_space) * a * np.sqrt(3))
                    if c % 2 == 0:
                        locarrayy[i] =  b
                    else:
                        locarrayy[i] = b + a * np.sqrt(3) / 2.
                    electronarray_new = np.asarray([locarrayx[i],locarrayy[i],jtype[i]])
                        
        electronarray[i] = np.asarray(electronarray_new)
    i = 0
    
    
    #plt.plot(electronarray[:,0], electronarray[:,1], 'ro')
    #plt.gca().set_aspect('equal')
    plt.grid()
    fig = plt.gcf()
    fig.set_size_inches(10, 10, forward=True)

    return electronarray
electronarray = electron_placement(N,t,x_space,y_space)

def electron_overlap_check(x_new, y_new, jtype_new, electronarray, i):
    x_array, y_array, jtype_array = electronarray[:, 0], electronarray[:, 1], electronarray[:,2]
    x, y, jtype = electronarray[i,0], electronarray[i,1], electronarray[i,2]
    length = len(x_array)
    electronarray_new = np.asarray([x_new, y_new, jtype_new])
    
    for j in np.arange(length-1):
        if i == j:
            j += 1
        if np.array_equiv(electronarray_new, electronarray[j]) == 1:
            new_pos = motions(x,y,jtype,i,T)
            x_new, y_new, jtype_new = new_pos[0], new_pos[1], new_pos[2]
            
    return np.asarray([x_new, y_new, jtype_new])

def prob(x,y,T,jtype): 
    if (jtype % 2.0) == 0:
        x1 = x + a
        y1 = y
        
        x2 = x - a/2.0
        y2 = y + np.sqrt(3.0)*a/2.0
        
        x3 = x - a/2.0
        y3 = y - np.sqrt(3.0)*a/2.0
    else:
        x1 = x - a
        y1 = y
        
        x2 = x + a/2.0
        y2 = y - np.sqrt(3.0)*a/2.0
        
        x3 = x + a/2.0
        y3 = y + np.sqrt(3.0)*a/2.0
        
    hop1 = x1,y1,jtype
    hop2 = x2,y2,jtype
    hop3 = x3,y3,jtype
    
    counter = 0
    probval1 = 1
    probval2 = 1
    probval3 = 1
    probvalstay = 1
    
    for j in range(len(electronarray)):
        if np.array_equiv(hop1, electronarray[j]) == 1:
            counter += 1
            probval1 = 0
        if np.array_equiv(hop2, electronarray[j]) == 1:
            counter += 1
            probval2 = 0
        if np.array_equiv(hop3, electronarray[j]) == 1:
            counter += 1
            probval3 = 0
            
    sites = 3 - counter
    #k = 8.6 * 10e-5
    k = 1
    
    Ehop = 38.1212 #eV, equals atomic energy (calculated via Rydeberg Formula) plus hopping energy (approx. 2.6 eV)
    Estay = 35.52 #eV, atomic energy calculated using Rydbergs formula
    
    #Ef = 2.9kT
    
    b = (-Ehop/(1.0*k*T))
    c = (-Estay/(1.0*k*T))
    #b = (-(2.9+2.6/(1.0*k*T)))
    #c = (-2.9)
    
    probvalhop = (Decimal(b).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    probvalstay = (Decimal(c).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    
    probvalhop = float(probvalhop)
    probvalstay = float(probvalstay)
    
    if probval1 == 1:
        probval1 = probvalhop
    if probval2 == 1:
        probval2 = probvalhop
    if probval3 == 1:
        probval3 = probvalhop
        
    z = [probval1,probval2,probval3,probvalstay]
    
    
    return z

def motions(x,y,jtype,i,T):
    
    rand = np.random.random()
    new_pos = np.zeros(3)
    
    z = prob(x,y,T,jtype)
    rand *= np.sum(z)
    if (jtype % 2.0) == 0:
        if rand < z[0]:
            x_new = x + a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x - a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x - a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
    else:
        if rand < z[0]:
            x_new = x - a
            y_new = y
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]):
            x_new = x + a/2.0
            y_new = y - np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        elif rand < (z[0]+z[1]+z[2]):
            x_new = x + a/2.0
            y_new = y + np.sqrt(3.0)*a/2.0
            jtype_new = jtype + 1
        else:
            x_new, y_new, jtype_new = x, y, jtype
        
        
    return np.asarray([x_new,y_new,jtype_new])

def call_function(electronarray,t,N,T):
    new_electron = []
    electrons = np.zeros([t,N,3]) #an array of each electrons movements over time steps
    change = np.zeros([t,N,3])
    electronarray_old = electronarray
    j_avg = []
    for j in range(t):
        for i in range(N-1):
            new_electron = motions(electronarray[i,0],electronarray[i,1],electronarray[i,2],i,T)
            electronarray[i,0], electronarray[i,1], electronarray[i,2] = new_electron[0], new_electron[1], new_electron[2]
            if j == (t-1):
                j_avg.append(new_electron[2])
        #print electronarray
        electrons[j,:,:] = np.asarray([electronarray])
        change[j,:,:] = np.asarray(electronarray - electronarray_old)
        #can be used to make test cases
        #jtype column can tell us total distance traveled, (final iteration pos - start pos) gives total displacement
    print np.shape(electrons)
    j_avg = np.average(j_avg)
    print('average j is', j_avg)
    return electrons, j_avg
electrons,j_avg = call_function(electronarray,t,N,T)

for i in xrange(N):
    plt.plot(electrons[:,i,0],electrons[:,i,1])
    plt.title('%d electrons on a layer of Graphene' % N)
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.gca().set_aspect('equal')
    plt.grid()

fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
#fig.savefig('test2png.png', dpi=100)
# Out:
# (100L, 100L, 3L)
# ('average j is', 74.98989898989899)

# %%
#Zoom in on original hopping probability sweep to get a better defined beginning of the curve (resolution is limited due to
#Excessive computational time)

T = 12000
q = np.zeros([N,3])

val = ((T-100)/100)
temp = []
r = []
g = []
for i in range(100,T+100,1000):
    q = electron_placement(N,t,x_space,y_space)
    T = i
    print('the temperature is %d' % T)
    temp.append(T)
    w,o = call_function(q,t,N,T)
    o = 1.0 * o / t
    #o = j_avg
    g.append(o)
    print('the average hopping probability at temperature %f is %f' % (T, o))
    print(o)
    electronarray = np.zeros([N,3])
    locarrayx = np.zeros(N)
    locarrayy = np.zeros(N)
    jtype = np.zeros(N)
plt.plot(temp,g, 'o')
plt.title('hopping probability versus temperature')
# Out:
# the temperature is 100
# (100L, 100L, 3L)
# ('average j is', 74.181818181818187)
# the average hopping probability at temperature 100.000000 is 0.741818
# 0.741818181818
# the temperature is 1100
# (100L, 100L, 3L)
# ('average j is', 75.121212121212125)
# the average hopping probability at temperature 1100.000000 is 0.751212
# 0.751212121212
# the temperature is 2100
# (100L, 100L, 3L)
# ('average j is', 75.252525252525245)
# the average hopping probability at temperature 2100.000000 is 0.752525
# 0.752525252525
# the temperature is 3100
# (100L, 100L, 3L)
# ('average j is', 75.222222222222229)
# the average hopping probability at temperature 3100.000000 is 0.752222
# 0.752222222222
# the temperature is 4100
# (100L, 100L, 3L)
# ('average j is', 74.383838383838381)
# the average hopping probability at temperature 4100.000000 is 0.743838
# 0.743838383838
# the temperature is 5100
# (100L, 100L, 3L)
# ('average j is', 74.98989898989899)
# the average hopping probability at temperature 5100.000000 is 0.749899
# 0.749898989899
# the temperature is 6100
# (100L, 100L, 3L)
# ('average j is', 74.98989898989899)
# the average hopping probability at temperature 6100.000000 is 0.749899
# 0.749898989899
# the temperature is 7100
# (100L, 100L, 3L)
# ('average j is', 75.272727272727266)
# the average hopping probability at temperature 7100.000000 is 0.752727
# 0.752727272727
# the temperature is 8100
# (100L, 100L, 3L)
# ('average j is', 74.878787878787875)
# the average hopping probability at temperature 8100.000000 is 0.748788
# 0.748787878788
# the temperature is 9100
# (100L, 100L, 3L)
# ('average j is', 75.121212121212125)
# the average hopping probability at temperature 9100.000000 is 0.751212
# 0.751212121212
# the temperature is 10100
# (100L, 100L, 3L)
# ('average j is', 75.070707070707073)
# the average hopping probability at temperature 10100.000000 is 0.750707
# 0.750707070707
# the temperature is 11100
# (100L, 100L, 3L)
# ('average j is', 74.424242424242422)
# the average hopping probability at temperature 11100.000000 is 0.744242
# 0.744242424242

# %%
plt.loglog(temp,g)
plt.grid()
plt.title('log plot of hopping probability versus T(K)')

# %% [markdown]
# ________________________________

# %% [markdown]
# Function below is for sweeping the carrier concentration with temperature, not taking into account positional motion or overlap, due to computational time strain

# %% [markdown]
# ________________________________

# %%
base_N = 2e11 / 0.7465017156536999
N = base_N

a = 1
t = 20
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from decimal import *
getcontext().prec = 13
Narray = []
Tarray = []
conducarray = []
probsarray = []
def carrier_density(T):
    #at room temp (300 K) should be 9*10e10
    Vf = 3*10**8 #(cm/s) fermi velocity is about 1/100 speed of light
    k = 8.617*10**-5 #(eV/K)
    h_bar = 6.582*10**-16 #eV*s
    N = (np.pi/6.) * ((k*T**2)/(1.0*h_bar*Vf))**2 #(e/cm^2), for graphene sheet (fairly resembles literature)
    width = 50*10-7
    Egap = 2.0*np.pi*h_bar*Vf/(width)
    #N = (4.0/(width))*np.sqrt(np.pi*k*T/Egap)*np.exp(-Egap/(2.0*k*T))
    return N

def prob(T): #Removed motions and location tracking, and therefore changes in probability based off of occupied neighbors.
             #This was done for computational efficiency, since we are working with very large 

    sites = 3 
    
    #k = 8.6 * 10e-5
    k = 1
    
    #Ehop = 38.1212 #eV, equals atomic energy (calculated via Rydeberg Formula) plus hopping energy (approx. 2.6 eV)
    #Estay = 35.52 #eV, atomic energy calculated using Rydbergs formula
    
    #Below we implemented the k (momentum) terms into the energy terms used for the Boltzmann distribution
    
    ky = 2. * np.random.random() - 1. 
    kx = 2. *np.random.random() - 1.
    Ehop = 38.12121 * np.sqrt((1 + np.cos(ky*a/2.)**2 + 4*np.cos(ky*a/2.)*np.cos(kx*1.73*a/2.)))  #eV 
    Estay = 35.521 #eV, atomic energy calculated using Rydbergs formula
    #Ef = 2.9kT
    
    b = (-Ehop/(1.0*k*T))
    c = (-Estay/(1.0*k*T))
    #b = (-(2.9+2.6/(1.0*k*T))) #using the staying energy as the fermi energy, which is 2.9kT
    #c = (-2.9)
    
    probvalhop = (Decimal(b).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp())) #used decimal module so would not go to zero
    probvalstay = (Decimal(c).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))#for low T
    
    probvalhop = float(probvalhop)
    probvalstay = float(probvalstay)
    
    z = 3 * probvalhop #removed the possibility of overlap and merely calculated the hopping probability, as factoring in 
                       #change in location and possibility of overlap were not majorly significant to our results and made 
                       #computational time too large for us to reasonably commit to. 
    
    return z
for i in range(10,150):
    T = i
    N = carrier_density(T)
    Narray.append(N)
    Tarray.append(T)
    #print('N initially is %d' % N)

    
    q = prob(T)
    #q *= 15e11
    conduc = N * q
    conducarray.append(conduc)
    probsarray.append(q)
#plt.loglog(Tarray,probsarray)
plt.plot(Tarray,Narray)

# %%
#plt.plot(Tarray,probsarray)
#plt.plot(Tarray,Narray)
plt.loglog(Tarray,conducarray)

# %%
plt.plot(Tarray,probsarray)
z=[]
for i in range(10,150):
    print(Tarray[i],probsarray[i])
# Out:
# (20, 0.7248428110928999)
# (21, 0.7260757549617)
# (22, 0.7271936227436999)
# (23, 0.728211791481)
# (24, 0.7291430177298001)
# (25, 0.7299979725309)
# (26, 0.7307856505536)
# (27, 0.7315136866223999)
# (28, 0.7321886031756)
# (29, 0.7328160056196)
# (30, 0.7334007379299)
# (31, 0.7339470076268999)
# (32, 0.7344584869311)
# (33, 0.7349383952289)
# (34, 0.7353895667538)
# (35, 0.735814506489)
# (36, 0.7362154366092)
# (37, 0.7365943352814001)
# (38, 0.7369529692482)
# (39, 0.7372929213324)
# (40, 0.7376156137526999)
# (41, 0.7379223279834)
# (42, 0.7382142217409999)
# (43, 0.7384923435663)
# (44, 0.7387576453940999)
# (45, 0.7390109934258)
# (46, 0.7392531775665)
# (47, 0.7394849196416999)
# (48, 0.7397068805763001)
# (49, 0.7399196666826)
# (50, 0.7401238351863)
# (51, 0.7403198990934)
# (52, 0.7405083314922001)
# (53, 0.7406895693591)
# (54, 0.7408640169408)
# (55, 0.7410320487606)
# (56, 0.741194012301)
# (57, 0.7413502304007)
# (58, 0.7415010033996)
# (59, 0.7416466110672)
# (60, 0.7417873143315)
# (61, 0.7419233568405)
# (62, 0.7420549663671)
# (63, 0.7421823560838)
# (64, 0.7423057257111)
# (65, 0.7424252625639001)
# (66, 0.7425411424995)
# (67, 0.7426535307804001)
# (68, 0.7427625828594)
# (69, 0.7428684450978)
# (70, 0.7429712554197)
# (71, 0.743071143912)
# (72, 0.7431682333719)
# (73, 0.7432626398121)
# (74, 0.7433544729213)
# (75, 0.7434438364908)
# (76, 0.7435308288039)
# (77, 0.7436155429983)
# (78, 0.7436980673964)
# (79, 0.7437784858149)
# (80, 0.7438568778459)
# (81, 0.7439333191215001)
# (82, 0.7440078815571)
# (83, 0.7440806335758)
# (84, 0.7441516403184)
# (85, 0.7442209638371999)
# (86, 0.7442886632796)
# (87, 0.7443547950516)
# (88, 0.7444194129786)
# (89, 0.74448256845)
# (90, 0.7445443105551)
# (91, 0.7446046862103)
# (92, 0.7446637402791)
# (93, 0.7447215156819)
# (94, 0.7447780535004)
# (95, 0.7448333930757001)
# (96, 0.7448875720989)
# (97, 0.7449406266972)
# (98, 0.7449925915125)
# (99, 0.7450434997800001)
# (100, 0.7450933833947999)
# (101, 0.7451422729839)
# (102, 0.7451901979641)
# (103, 0.7452371866026)
# (104, 0.7452832660737)
# (105, 0.7453284625098)
# (106, 0.7453728010521)
# (107, 0.7454163058953001)
# (108, 0.7454590003338)
# (109, 0.7455009068016)
# (110, 0.7455420469128)
# (111, 0.7455824414973)
# (112, 0.745622110638)
# (113, 0.7456610737023001)
# (114, 0.7456993493742)
# (115, 0.7457369556849)
# (116, 0.7457739100398)
# (117, 0.7458102292461)
# (118, 0.7458459295392)
# (119, 0.7458810266046)
# (120, 0.7459155356022)
# (121, 0.7459494711897)
# (122, 0.7459828475403001)
# (123, 0.746015678364)
# (124, 0.7460479769271)
# (125, 0.7460797560683999)
# (126, 0.7461110282175)
# (127, 0.7461418054107)
# (128, 0.7461720993063)
# (129, 0.7462019211984)
# (130, 0.7462312820331)
# (131, 0.7462601924208)
# (132, 0.7462886626473)
# (133, 0.7463167026885)
# (134, 0.7463443222221)
# (135, 0.7463715306359999)
# (136, 0.7463983370414999)
# (137, 0.7464247502829)
# (138, 0.7464507789462)
# (139, 0.7464764313702)
# (140, 0.7465017156536999)
# (141, 0.7465266396645)
# (142, 0.7465512110487)
# (143, 0.7465754372367)
# (144, 0.7465993254516)
# (145, 0.7466228827173)
# (146, 0.7466461158633)
# (147, 0.7466690315330999)
# (148, 0.7466916361899001)
# (149, 0.7467139361226001)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-74960916d3ee> in <module>()
#       2 z=[]
#       3 for i in range(10,150):
# ----> 4     print(Tarray[i],probsarray[i])
#
# IndexError: list index out of range

# %%
a = 1
t = 20
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from decimal import *
getcontext().prec = 36
Narray = []
Tarray = []
conducarray = []
probsarray = []
def carrier_density(T):
    #at room temp (300 K) should be 9*10e10
    Vf = 3*10**8 #(cm/s) fermi velocity is about 1/100 speed of light
    k = 8.617*10**-5 #(eV/K)
    h_bar = 6.582*10**-16 #eV*s
    width = 50 * 10**-7 #in cm
    Egap = 2.0*np.pi*h_bar*Vf/(width)
    #print('Egap is equal to %f' % Egap)
    expval = -1.0*Egap/(2.0*k*T)
    exponent = Decimal(expval).exp()
    exponent = float(exponent)
    #print('exponent is equal to', exponent)
    #N = (np.pi/6.) * ((k*T**2)/(1.0*h_bar*Vf))**2 #(e/cm^2) #(graphene sheet)
    N = (4.0/(width))*np.sqrt(1.0*np.pi*k*T/Egap)*exponent #(graphene nanoribbon)
    N = int(N) 
    #print('N in carrier_density is equal to %f' % N)
    return N

def prob(T): #Removed motions and location tracking, and therefore changes in probability based off of occupied neighbors.
             #This was done for computational efficiency, since we are working with very large 

    sites = 3 
    
    #k = 8.6 * 10e-5
    k = 1
    
    #Ehop = 38.1212 #eV, equals atomic energy (calculated via Rydeberg Formula) plus hopping energy (approx. 2.6 eV)
    #Estay = 35.52 #eV, atomic energy calculated using Rydbergs formula
    
    #Below we implemented the k (momentum) terms into the energy terms used for the Boltzmann distribution
    
    ky = 2. * np.random.random() - 1. 
    kx = 2. *np.random.random() - 1.
    Ehop = 38.12121 * np.sqrt((1 + np.cos(ky*a/2.)**2 + 4*np.cos(ky*a/2.)*np.cos(kx*1.73*a/2.)))  #eV 
    Estay = 35.521 #eV, atomic energy calculated using Rydbergs formula
    #Ef = 2.9kT
    
    #b = (-Ehop/(1.0*k*T))
    #c = (-Estay/(1.0*k*T))
    b = (-(2.9+2.6/(1.0*k*T)))
    c = (-2.9)
    

    
    probvalhop = (Decimal(b).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    probvalstay = (Decimal(c).exp())/(sites * (Decimal(b).exp()) + (Decimal(c).exp()))
    
    probvalhop = float(probvalhop)
    probvalstay = float(probvalstay)
    
    z = 3 * probvalhop
    
    return z

N1array = []
base_N = 2*10**11 / 0.7465017156536999 #Found using our probability function and the carrier density from the log graph in a
                                       #research paper online (tight-binding model literature we referred to does not depict
                                       #being a variable number of electrons, let alone an equation for such, so we assumed a
                                       #fixed number of total electrons able to hop and calculated a base number allowing our
                                       #model to best emulate the conditions in the experiment

for i in range(1,500): #Temperature sweep
    T = i
    N = base_N
    N1 = carrier_density(T)
    #print('N is equal to %f' % N)
    N1array.append(N1)
    Tarray.append(T)
    #print('N initially is %d' % N)
    q = prob(T)
    #q *= 15e11
    conduc = N * q
    conducarray.append(conduc)
    probsarray.append(q)
#plt.loglog(Tarray,probsarray)
plt.loglog(Tarray,conducarray, 'ko--',  mfc='none',label = 'tight binding')
plt.legend(loc = 'upper right')
plt.ylim(10**7,3*10**12)
plt.title('Tight Binding Model Simulation')
plt.xlabel('Temperature(K)')
plt.ylabel('Carrier Density (electrons / cm^2)')
plt.grid()
plt.gca().set_aspect('equal')
fig = plt.gcf()
fig.set_size_inches(10, 10, forward=True)
